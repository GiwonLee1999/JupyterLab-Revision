# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col ='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col ='Column')
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df.shape
# Out:
# (85, 1)

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index().head() # sort the index alphabetical order
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %%
df.shape # gives rows and cols
# Out:
# (88883, 84)

# %%
# df.info() # all the information

# %%
pd.set_option('display.max_columns', 85) # Enables to view the entire columns
pd.set_option('display.max_rows', 85) # Enables to view the entire rows

# %%
schema_df.head()
schema_df.tail()
# Out:
#                                                    QuestionText
# Column
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...

# %%
dataframe = pd.DataFrame() # Can insert dictionary

# %%
# dataframe['Column'] returns column
# dataframe.Column returns same thing as above
# dataframe[['first', 'last']] returns multiple serises of column
# dataframe.columns # returns all the columns - name
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# iloc: Use index to retrieve a row

# %%
df.iloc[[0,1]] # returns from 0 to 1
df.iloc[[0,1], 2] # returns from 0 to 1 and second column elements only
# Out:
# Respondent
# 1                      Never
# 2    Less than once per year
# Name: OpenSourcer, dtype: object

# %% [markdown]
# loc: Returns Columns and rows elements

# %%
#df.loc[0] # First row with the column names
#df.loc[[0,1]] # First to second row
#df.loc[[0,1], 'Age'] # First to second row/ Age columns
#df.loc[[1], ['Age', 'Employment']] # First to second row/ Age columns

# %% [markdown]
# # Part2: loc, iloc, shape

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Country'].value_counts()

# %%
df['Country']
# Out:
# Respondent
# 1                United Kingdom
# 2        Bosnia and Herzegovina
# 3                      Thailand
# 4                 United States
# 5                       Ukraine
#                   ...
# 88377                    Canada
# 88601                       NaN
# 88802                       NaN
# 88816                       NaN
# 88863                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
#df.loc[0:2, 'Country']

# %%
#df.loc[0:10,'TechList':'CompTotal']

# %% [markdown]
# # Indexes
# #### Go to Pandas Basic Function

# %%
#df.loc[1]

# %%
# schema_df.sort_index(ascending=True)

# %% [markdown]
# ## Filtering Data

# %%
high_salary = (df['ConvertedComp'] > 70000)
countries = ['United States', 'India', 'United Kingdom','Germany','Canada']
filt = (df['Country'].isin(countries)) & (high_salary)

# %%
# How to filter between multiple elements. **
filtLanguage = df['LanguageWorkedWith'].str.contains('Python', na=False) # na means remove NaN- not a number value
df.loc[filtLanguage,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                            Country  \
# Respondent
# 1                   United Kingdom
# 2           Bosnia and Herzegovina
# 4                    United States
# 5                          Ukraine
# 8                            India
# ...                            ...
# 84539               United Kingdom
# 85738                       Brazil
# 86566                  Switzerland
# 87739               Czech Republic
# 88212                        Spain
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python            NaN
# 2                                         C++;HTML/CSS;Python            NaN
# 4                                         C;C++;C#;Python;SQL        61000.0
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA            NaN
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...

# %%
df.loc[filt,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26           United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# ...                    ...                                                ...
# 88873               Canada               HTML/CSS;JavaScript;PHP;Python;R;SQL
# 88874        United States                               C++;Python;Scala;SQL
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
#
# ...

# %%
# Alter the column name

# %%
df.rename(columns ={'ConvertedComp': 'SalaryUSD'}, inplace = True)

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      NaN
# 2                      I am a student who is learning to code      NaN
# 3           I am not primarily a developer, but I write co...      NaN
# 4                              I am a developer by profession      NaN
# 5                              I am a developer by profession      NaN
# ...                                                       ...      ...
# 88377                                                     NaN      NaN
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
# 88863                                                     NaN      NaN
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_values(by=['Country', 'SalaryUSD'],ascending = [True, False], inplace = True)

# %%
df.loc[df['SalaryUSD']>1,['Country', 'SalaryUSD']].head()
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0

# %%
df['SalaryUSD'].nlargest(10) # n largest values
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 22013    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
df.nsmallest(1, 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 28638       I am a developer by profession      NaN
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 28638       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment      Country  \
# Respondent
# 28638       Independent contractor, freelancer, or self-em...  Afghanistan
#
#            Student                                    EdLevel  \
# Respondent
# 28638          NaN  Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                       UndergradMajor EduOther OrgSize DevType YearsCode  \
# Respondent
# 28638       I never declared a major      NaN     NaN     NaN        36
#
#            Age1stCode YearsCodePro          CareerSat             JobSat  \
# Respondent
# ...

# %% [markdown]
# # Aggregating & Grouping

# %%
df['SalaryUSD'].head()
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median() # Median Salary
# Out:
# 57287.0

# %%
df.median() # returns any numerical value cols
# Out:
# /var/folders/j4/qgpy44qx7398qzznf1tmwnk40000gr/T/ipykernel_3392/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Hobbyist           NaN
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe() # Overall aggregate values for numerical columns
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True,ascending=False)*100
# Out:
# Reddit                      17.023343
# YouTube                     16.379076
# WhatsApp                    15.807051
# Facebook                    15.606902
# Twitter                     13.498822
# Instagram                    7.414996
# I don't use social media     6.577685
# LinkedIn                     5.330602
# WeChat 微信                    0.789938
# Snapchat                     0.743750
# VK ВКонта́кте                0.714142
# Weibo 新浪微博                   0.066322
# Youku Tudou 优酷               0.024871
# Hello                        0.022502
# Name: SocialMedia, dtype: float64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States').head(1)
# Out:
#                                 MainBranch Hobbyist OpenSourcer  \
# Respondent
# 4           I am a developer by profession       No       Never
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# 4           Employed full-time  United States      No
#
#                                              EdLevel  \
# Respondent
# 4           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 4           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 4           Taken an online course in programming or softw...
#
#                          OrgSize                DevType YearsCode Age1stCode  \
# Respondent
# ...

# %%
filt = df['Country'] == 'United States'
# Most used website broken down by Country
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
# Most used website broken down by Country
country_grp['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc[['Germany','South Korea']]
# Out:
# Country
# Germany        63016.0
# South Korea    40950.5
# Name: ConvertedComp, dtype: float64

# %%
country_grp['ConvertedComp'].agg(['median', 'mean', 'max']).loc[['Germany', 'South Korea']]
# Out:
#               median           mean        max
# Country
# Germany      63016.0  109256.884066  2000000.0
# South Korea  40950.5   79716.100000  1000000.0

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum() # how many people knows python in india
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum()).head(20)
# Out:
# Country
# Afghanistan              8
# Albania                 23
# Algeria                 40
# Andorra                  0
# Angola                   2
# Antigua and Barbuda      0
# Argentina              191
# Armenia                 28
# Australia              790
# Austria                338
# Azerbaijan              17
# Bahamas                  2
# Bahrain                  4
# Bangladesh             204
# Barbados                 1
# Belarus                 69
# Belgium                296
# Belize                   1
# Benin                    3
# Bhutan                   1
# Name: LanguageWorkedWith, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# percentage of each country that knows python
python_df = pd.concat([country_respondents, country_uses_python],axis='columns', sort=False)
python_df.rename(columns={'Country':'NumRespondents', 'LanguageWorkedWith':'NumKnowsPython'},inplace=True)

# %%
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# United States               20949           10083
# India                        9061            3105
# Germany                      5866            2451
# United Kingdom               5737            2384
# Canada                       3395            1558
# ...                           ...             ...
# Tonga                           1               0
# Timor-Leste                     1               1
# North Korea                     1               0
# Brunei Darussalam               1               0
# Chad                            1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                    NumRespondents  NumKnowsPython  PctKnowsPython
# United States               20949           10083       48.131176
# India                        9061            3105       34.267741
# Germany                      5866            2451       41.783157
# United Kingdom               5737            2384       41.554820
# Canada                       3395            1558       45.891016
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1      100.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython',ascending = False, inplace=True)

# %%
python_df[python_df['NumRespondents'] > 1000].sort_values(by='NumRespondents', ascending = False)
# Out:
#                     NumRespondents  NumKnowsPython  PctKnowsPython
# United States                20949           10083       48.131176
# India                         9061            3105       34.267741
# Germany                       5866            2451       41.783157
# United Kingdom                5737            2384       41.554820
# Canada                        3395            1558       45.891016
# France                        2391            1054       44.081974
# Brazil                        1948             767       39.373717
# Poland                        1922             751       39.073881
# Australia                     1903             790       41.513400
# Netherlands                   1852             767       41.414687
# Russian Federation            1694             708       41.794569
# Spain                         1604             641       39.962594
# Italy                         1576             625       39.657360
# ...

# %% [markdown]
# # Cleaning Data

# %%
na_vals = ['NA','Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col ='Respondent', na_values =na_vals)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array([ 4., nan,  3., 16., 13.,  6.,  8., 12.,  2.,  5., 17., 10., 14.,
#        35.,  7.,  0., 30.,  9., 26., 40., 19., 15., 20., 28., 25.,  1.,
#        22., 11., 33., 50., 41., 18., 34., 24., 23., 42., 27., 21., 36.,
#        32., 39., 38., 31., 37., 51., 29., 44., 45., 48., 46., 43., 47.,
#        49.])

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
